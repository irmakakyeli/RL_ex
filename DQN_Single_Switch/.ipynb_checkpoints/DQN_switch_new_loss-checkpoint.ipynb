# %% [raw]
# !pip install stable-baselines3==2.0.0
# !pip install numpy

# %%
import os

# %%
import numpy as np
import sys
import csv
from IPython.display import clear_output
from stable_baselines3 import DQN
import requests
import datetime
import torch

# %%
clear_output(wait=True)

# %% [raw]
# try:
#   !rm -rf boptestGym
# except:
#   pass
# !git clone -b master https://github.com/ibpsa/project1-boptest-gym.git boptestGym

# %%
url_api = 'https://api.boptest.net'
url = "http://localhost:80"
log_path = os.path.join("Logs")

# %%
sys.path.insert(0,'../boptestGym')
from boptestGymEnv import BoptestGymEnv
from boptestGymEnv import NormalizedObservationWrapper
from boptestGymEnv import DiscretizedActionWrapper

# %%
def denormalize(norm_vals, lo, hi): 
    return 0.5 * (norm_vals + 1.0) * (hi - lo) + lo

kelvin = lambda c: c + 273.15
celc = lambda k: k -273.15

# %%
bounds = {
    "T_in": (273,324),
    "T_out": (257,305),
    "Psol": (0, 862),
}

step_period_h = 0.5
floor_area = 16 * 12
low_setpoint_k  = kelvin(21.0)
high_setpoint_k = kelvin(24.0)

# %%
class BoptestGymEnvCustomReward(BoptestGymEnv):
    def reset(self, *args, **kwargs):
        obs, info = super().reset(**kwargs)
        self.last_obs = obs
        self.last_action=0
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        self.last_obs = obs
        self.last_action = action
        return obs, reward, terminated, truncated, info
    
    def get_reward(self):
        obs = self.last_obs
        action = self.last_action
        T_in_K_val = obs[0]
        discomfort = (max(0.0, low_setpoint_k  - T_in_K_val) +
                  max(0.0, T_in_K_val - high_setpoint_k)) * step_period_h
        energy = float(action) * 15.0 * step_period_h  / floor_area
        reward = -(discomfort + energy)

        #reward += self.objective_integrand
        self.objective_integrand = reward
        return reward

# %%
feb15 = 47 * 24*3600                    # Jan 1 → Feb 15 low data regime
june30 = 181 * 24 *3600                 # high data regime
episode_length = 7 * 24*3600            # 1 week episodes

# %%
def create_env(max_start):
    env = BoptestGymEnvCustomReward(url  = url,
                    testcase              = 'bestest_hydronic_heat_pump',
                    actions               = ['oveHeaPumY_u'],
                    observations          = {'reaTZon_y':(273.,324.), #0 / 50
                                             'weaSta_reaWeaTDryBul_y':(257.,305.), # -15 / 28.8
                                             'weaSta_reaWeaHDirNor_y':(0.,862.)
                                            },
                    random_start_time     = True,
                    max_episode_length    = 7 * 24*3600,
                    excluding_periods     = [(max_start, 365*24*3600)],
                    warmup_period         = 24*3600,
                    predictive_period     = 0,
                    regressive_period     = 4*1800,
                    step_period           = 1800
                               )
    env = NormalizedObservationWrapper(env)
    env = DiscretizedActionWrapper(env,n_bins_act=1)
    print("env created")
    return env

# %%
for data_regime in [6, 27]:
    for training_episodes in [25, 50]:
        print(f"training episode: {training_episodes}")
        if data_regime == 6:
            max_start = feb15 - episode_length      # last valid start time
            print("6 weeks")
        elif data_regime == 27:
            max_start = june30 - episode_length      # last valid start time
            print("27 weeks")
        env = create_env(max_start)    
        policy_kwargs = dict(
            net_arch=[64, 8],  
            activation_fn=torch.nn.ReLU
        )

        model = DQN('MlpPolicy',
            env,
            verbose=1,
            gamma=0.99,
            learning_rate=0.01,
            batch_size=64,
            buffer_size=20000,
            learning_starts=0,
            train_freq=1,
            target_update_interval=1000,
            tau=1.0,
            gradient_steps=1,
            exploration_fraction=0.1,          #ε-greedy?
            exploration_initial_eps=1.0,
            exploration_final_eps=0.05,
            policy_kwargs=policy_kwargs,
            tensorboard_log= log_path)
        
        total_timesteps = 336 * training_episodes 
        model.learn(total_timesteps= total_timesteps, tb_log_name = f"DQN_switch_1_{data_regime}_{training_episodes}") 
        model.save(f"Saved Models/DQN_switch_1_{data_regime}_{training_episodes}")
        print(f"model saved at: Saved Models/DQN_switch_1_{data_regime}_{training_episodes}")
        buffer_path = os.path.join( "Memory Buffers", f"DQN_switch_1_{data_regime}_{training_episodes}")
        model.save_replay_buffer(buffer_path)
        print("memory buffer saved")
        env.stop()
        del model
# Out:
# training episode: 25
# 6 weeks
# C:\Users\irmak\anaconda3\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_6_25_1
# C:\Users\irmak\AppData\Local\Temp\ipykernel_19928\2876087588.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   energy = float(action) * 15.0 * step_period_h  / floor_area
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -117     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 15       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 1344     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0712   |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 14       |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0462   |
# |    n_updates        | 2687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 15       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 4032     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0729   |
# |    n_updates        | 4031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 15       |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 5376     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0575   |
# |    n_updates        | 5375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -97.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 15       |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 6720     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0565   |
# |    n_updates        | 6719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 15       |
# |    time_elapsed     | 520      |
# |    total_timesteps  | 8064     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0971   |
# |    n_updates        | 8063     |
# ----------------------------------
# model saved at: Saved Models/DQN_switch_1_6_25
# memory buffer saved
# training episode: 50
# 6 weeks
# C:\Users\irmak\anaconda3\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_6_50_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -79.8    |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 15       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 1344     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0251   |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -54.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 15       |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.00417  |
# |    n_updates        | 2687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -38.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 16       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 4032     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.016    |
# |    n_updates        | 4031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -30.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 16       |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 5376     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0206   |
# |    n_updates        | 5375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -25.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 16       |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 6720     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0191   |
# |    n_updates        | 6719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -22.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16       |
# |    time_elapsed     | 487      |
# |    total_timesteps  | 8064     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0156   |
# |    n_updates        | 8063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 16       |
# |    time_elapsed     | 566      |
# |    total_timesteps  | 9408     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0129   |
# |    n_updates        | 9407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -18.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 16       |
# |    time_elapsed     | 648      |
# |    total_timesteps  | 10752    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0241   |
# |    n_updates        | 10751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -17.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 16       |
# |    time_elapsed     | 726      |
# |    total_timesteps  | 12096    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.023    |
# |    n_updates        | 12095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -16.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 16       |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 13440    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0142   |
# |    n_updates        | 13439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -15.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 16       |
# |    time_elapsed     | 885      |
# |    total_timesteps  | 14784    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.00815  |
# |    n_updates        | 14783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -15.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 16       |
# |    time_elapsed     | 964      |
# |    total_timesteps  | 16128    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.00356  |
# |    n_updates        | 16127    |
# ----------------------------------
# model saved at: Saved Models/DQN_switch_1_6_50
# memory buffer saved
# training episode: 25
# 27 weeks
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_27_25_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -1.1e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 16       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 1344     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0179   |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -568     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 17       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.012    |
# |    n_updates        | 2687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -384     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 17       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 4032     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.142    |
# |    n_updates        | 4031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -301     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 17       |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 5376     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0244   |
# |    n_updates        | 5375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -244     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 17       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 6720     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.106    |
# |    n_updates        | 6719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 17       |
# |    time_elapsed     | 470      |
# |    total_timesteps  | 8064     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.144    |
# |    n_updates        | 8063     |
# ----------------------------------
# model saved at: Saved Models/DQN_switch_1_27_25
# memory buffer saved
# training episode: 50
# 27 weeks
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_27_50_1
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.49e+03 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 15        |
# |    time_elapsed     | 86        |
# |    total_timesteps  | 1344      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 0.0242    |
# |    n_updates        | 1343      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.13e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 15        |
# |    time_elapsed     | 172       |
# |    total_timesteps  | 2688      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 0.0163    |
# |    n_updates        | 2687      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -980     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 15       |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 4032     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.127    |
# |    n_updates        | 4031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -826     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 16       |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 5376     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0707   |
# |    n_updates        | 5375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -725     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 16       |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 6720     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.0771   |
# |    n_updates        | 6719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -671     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16       |
# |    time_elapsed     | 491      |
# |    total_timesteps  | 8064     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.239    |
# |    n_updates        | 8063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -581     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 16       |
# |    time_elapsed     | 569      |
# |    total_timesteps  | 9408     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.132    |
# |    n_updates        | 9407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -564     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 16       |
# |    time_elapsed     | 646      |
# |    total_timesteps  | 10752    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.165    |
# |    n_updates        | 10751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -533     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 16       |
# |    time_elapsed     | 724      |
# |    total_timesteps  | 12096    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.38     |
# |    n_updates        | 12095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -483     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 16       |
# |    time_elapsed     | 801      |
# |    total_timesteps  | 13440    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.304    |
# |    n_updates        | 13439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -441     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 16       |
# |    time_elapsed     | 880      |
# |    total_timesteps  | 14784    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.404    |
# |    n_updates        | 14783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -419     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 16       |
# |    time_elapsed     | 958      |
# |    total_timesteps  | 16128    |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 0.374    |
# |    n_updates        | 16127    |
# ----------------------------------
# model saved at: Saved Models/DQN_switch_1_27_50
# memory buffer saved

# %% [raw]
# data_regime = 27
# training_episodes = 25
#
# if data_regime == 6:
#     max_start = feb15 - episode_length      # last valid start time
#     print("6 weeks")
# elif data_regime == 27:
#     max_start = june30 - episode_length      # last valid start time
#     print("27 weeks")
#
# env = create_env(max_start)
# policy_kwargs = dict(
#     net_arch=[64, 8],
#     activation_fn=torch.nn.ReLU
# )
#
# model = DQN('MlpPolicy',
#     env,
#     verbose=1,
#     gamma=0.99,
#     learning_rate=0.01,
#     batch_size=64,
#     buffer_size=20000,
#     learning_starts=0,
#     train_freq=1,
#     target_update_interval=1000,
#     tau=1.0,
#     gradient_steps=1,
#     exploration_fraction=0.1,          #ε-greedy?
#     exploration_initial_eps=1.0,
#     exploration_final_eps=0.05,
#     policy_kwargs=policy_kwargs,
#     tensorboard_log= log_path)
#
# total_timesteps = 336 * training_episodes
# model.learn(total_timesteps= total_timesteps, tb_log_name = f"DQN_switch_1_{data_regime}_{training_episodes}_r")
# model.save(f"Saved Models/DQN_switch_1_{data_regime}_{training_episodes}_r")
# print(f"model saved at: Saved Models/DQN_switch_1_{data_regime}_{training_episodes}_r")
# buffer_path = os.path.join( "Memory Buffers", f"DQN_switch_1_{data_regime}_{training_episodes}_r")
# model.save_replay_buffer(buffer_path)
# print("memory buffer saved")
# env.stop()
