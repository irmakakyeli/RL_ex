# %% [raw]
# !pip install stable-baselines3==2.0.0
# !pip install numpy

# %%
import os

# %%
import numpy as np
import sys
import csv
from IPython.display import clear_output
from stable_baselines3 import DQN
import requests
import datetime
import torch

# %%
clear_output(wait=True)

# %% [raw]
# try:
#   !rm -rf boptestGym
# except:
#   pass
# !git clone -b master https://github.com/ibpsa/project1-boptest-gym.git boptestGym

# %%
url_api = 'https://api.boptest.net'
url = "http://localhost:80"
log_path = os.path.join("Logs")
step_period_h = 0.5
floor_area = 16 * 12

# %%
sys.path.insert(0,'../boptestGym')
from boptestGymEnv import BoptestGymEnv
from boptestGymEnv import NormalizedObservationWrapper
from boptestGymEnv import DiscretizedActionWrapper

# %%
def denormalize(norm_vals, lo, hi): 
    return 0.5 * (norm_vals + 1.0) * (hi - lo) + lo

kelvin = lambda c: c + 273.15
celc = lambda k: k -273.15

# %%
bounds = {
    "T_in": (273,324),
    "T_out": (257,305),
    "Psol": (0, 862),
}

low_setpoint_k  = kelvin(21.0)
high_setpoint_k = kelvin(24.0)

# %%
class BoptestGymEnvCustomReward(BoptestGymEnv):
    def reset(self, *args, **kwargs):
        obs, info = super().reset(**kwargs)
        self.last_obs = obs
        self.last_action=0
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        self.last_obs = obs
        self.last_action = action
        return obs, reward, terminated, truncated, info
    
    def get_reward(self):
        obs = self.last_obs
        action = self.last_action
        T_in_K_val = obs[0]
        discomfort = (max(0.0, low_setpoint_k  - T_in_K_val) +
                  max(0.0, T_in_K_val - high_setpoint_k)) * step_period_h
        energy = float(action) * 15.0 * step_period_h  / floor_area
        reward = -(discomfort + energy)

        reward += self.objective_integrand
        self.objective_integrand = reward
        return reward

# %%
feb15 = 47 * 24*3600                    # Jan 1 → Feb 15 low data regime
june30 = 181 * 24 *3600                 # high data regime
episode_length = 7 * 24*3600            # 1 week episodes

# %%
def create_env(max_start):
    env = BoptestGymEnvCustomReward(url  = url,
                    testcase              = 'bestest_hydronic_heat_pump',
                    actions               = ['oveHeaPumY_u'],
                    observations          = {'reaTZon_y':(273.,324.), #0 / 50
                                             'weaSta_reaWeaTDryBul_y':(257.,305.), # -15 / 28.8
                                             'weaSta_reaWeaHDirNor_y':(0.,862.)
                                            },
                    random_start_time     = True,
                    max_episode_length    = 7 * 24*3600,
                    excluding_periods     = [(max_start, 365*24*3600)],
                    warmup_period         = 24*3600,
                    predictive_period     = 0,
                    regressive_period     = 4*1800,
                    step_period           = 1800
                               )
    env = NormalizedObservationWrapper(env)
    env = DiscretizedActionWrapper(env,n_bins_act=1)
    print("env created")
    return env

# %%
for data_regime in [6, 27]:
    for training_episodes in [25, 50]:
        print(f"training episode: {training_episodes}")
        if data_regime == 6:
            max_start = feb15 - episode_length      # last valid start time
            print("6 weeks")
        elif data_regime == 27:
            max_start = june30 - episode_length      # last valid start time
            print("27 weeks")
        env = create_env(max_start)    
        policy_kwargs = dict(
            net_arch=[64, 8],  
            activation_fn=torch.nn.ReLU
        )

        model = DQN('MlpPolicy',
            env,
            verbose=1,
            gamma=0.99,
            learning_rate=0.01,
            batch_size=64,
            buffer_size=20000,
            learning_starts=0,
            train_freq=1,
            target_update_interval=1000,
            tau=1.0,
            gradient_steps=1,
            exploration_fraction=0.1,          #ε-greedy?
            exploration_initial_eps=1.0,
            exploration_final_eps=0.05,
            policy_kwargs=policy_kwargs,
            tensorboard_log= log_path)
        
        total_timesteps = 336 * training_episodes 
        model.learn(total_timesteps= total_timesteps, tb_log_name = f"DQN_switch_1_{data_regime}_{training_episodes}") 
        model.save(f"Saved Models/DQN_switch_1_{data_regime}_{training_episodes}")
        print(f"model saved at: Saved Models/DQN_switch_1_{data_regime}_{training_episodes}")
        buffer_path = os.path.join( "Memory Buffers", f"DQN_switch_1_{data_regime}_{training_episodes}")
        model.save_replay_buffer(buffer_path)
        print("memory buffer saved")
        env.stop()
# Out:
# training episode: 25
# 6 weeks
# C:\Users\irmak\anaconda3\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_6_25_1
# C:\Users\irmak\AppData\Local\Temp\ipykernel_25228\399620426.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   energy = float(action) * 15.0 * step_period_h  / floor_area
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.27e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 18        |
# |    time_elapsed     | 74        |
# |    total_timesteps  | 1344      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 73.7      |
# |    n_updates        | 1343      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -1.4e+05 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 18       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 2688     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 119      |
# |    n_updates        | 2687     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.57e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 19        |
# |    time_elapsed     | 211       |
# |    total_timesteps  | 4032      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 167       |
# |    n_updates        | 4031      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.61e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 19        |
# |    time_elapsed     | 280       |
# |    total_timesteps  | 5376      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 147       |
# |    n_updates        | 5375      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.67e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 19        |
# |    time_elapsed     | 351       |
# |    total_timesteps  | 6720      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 116       |
# |    n_updates        | 6719      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.65e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 19        |
# |    time_elapsed     | 422       |
# |    total_timesteps  | 8064      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 189       |
# |    n_updates        | 8063      |
# -----------------------------------
# model saved at: Saved Models/DQN_switch_1_6_25
# memory buffer saved
# training episode: 50
# 6 weeks
# C:\Users\irmak\anaconda3\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_6_50_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -6.8e+04 |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 18       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 1344     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 87.8     |
# |    n_updates        | 1343     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.01e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 18        |
# |    time_elapsed     | 143       |
# |    total_timesteps  | 2688      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 81        |
# |    n_updates        | 2687      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.12e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 18        |
# |    time_elapsed     | 214       |
# |    total_timesteps  | 4032      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 127       |
# |    n_updates        | 4031      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.28e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 18        |
# |    time_elapsed     | 285       |
# |    total_timesteps  | 5376      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 103       |
# |    n_updates        | 5375      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -1.4e+05 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 18       |
# |    time_elapsed     | 355      |
# |    total_timesteps  | 6720     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 125      |
# |    n_updates        | 6719     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.47e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 18        |
# |    time_elapsed     | 425       |
# |    total_timesteps  | 8064      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 110       |
# |    n_updates        | 8063      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.53e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 19        |
# |    time_elapsed     | 494       |
# |    total_timesteps  | 9408      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 103       |
# |    n_updates        | 9407      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.54e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 18        |
# |    time_elapsed     | 565       |
# |    total_timesteps  | 10752     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 139       |
# |    n_updates        | 10751     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.57e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 19        |
# |    time_elapsed     | 635       |
# |    total_timesteps  | 12096     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 124       |
# |    n_updates        | 12095     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.57e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 19        |
# |    time_elapsed     | 705       |
# |    total_timesteps  | 13440     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 176       |
# |    n_updates        | 13439     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.55e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 19        |
# |    time_elapsed     | 776       |
# |    total_timesteps  | 14784     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 180       |
# |    n_updates        | 14783     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.51e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 19        |
# |    time_elapsed     | 845       |
# |    total_timesteps  | 16128     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 159       |
# |    n_updates        | 16127     |
# -----------------------------------
# model saved at: Saved Models/DQN_switch_1_6_50
# memory buffer saved
# training episode: 25
# 27 weeks
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_27_25_1
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.19e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 18        |
# |    time_elapsed     | 70        |
# |    total_timesteps  | 1344      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 55.1      |
# |    n_updates        | 1343      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.15e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 19        |
# |    time_elapsed     | 139       |
# |    total_timesteps  | 2688      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 104       |
# |    n_updates        | 2687      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.35e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 19        |
# |    time_elapsed     | 209       |
# |    total_timesteps  | 4032      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 250       |
# |    n_updates        | 4031      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.78e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 19        |
# |    time_elapsed     | 279       |
# |    total_timesteps  | 5376      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 183       |
# |    n_updates        | 5375      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -1.98e+05 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 19        |
# |    time_elapsed     | 348       |
# |    total_timesteps  | 6720      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 216       |
# |    n_updates        | 6719      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 336      |
# |    ep_rew_mean      | -2e+05   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 19       |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 8064     |
# | train/              |          |
# |    learning_rate    | 0.01     |
# |    loss             | 229      |
# |    n_updates        | 8063     |
# ----------------------------------
# model saved at: Saved Models/DQN_switch_1_27_25
# memory buffer saved
# training episode: 50
# 27 weeks
# env created
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Logs\DQN_switch_1_27_50_1
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -4.93e+04 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 18        |
# |    time_elapsed     | 74        |
# |    total_timesteps  | 1344      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 55.2      |
# |    n_updates        | 1343      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -6.89e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 18        |
# |    time_elapsed     | 144       |
# |    total_timesteps  | 2688      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 49.3      |
# |    n_updates        | 2687      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -7.62e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 18        |
# |    time_elapsed     | 217       |
# |    total_timesteps  | 4032      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 144       |
# |    n_updates        | 4031      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -7.57e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 18        |
# |    time_elapsed     | 291       |
# |    total_timesteps  | 5376      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 132       |
# |    n_updates        | 5375      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -7.73e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 18        |
# |    time_elapsed     | 370       |
# |    total_timesteps  | 6720      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 148       |
# |    n_updates        | 6719      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.18e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 18        |
# |    time_elapsed     | 441       |
# |    total_timesteps  | 8064      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 138       |
# |    n_updates        | 8063      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.82e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 18        |
# |    time_elapsed     | 511       |
# |    total_timesteps  | 9408      |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 117       |
# |    n_updates        | 9407      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.84e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 18        |
# |    time_elapsed     | 581       |
# |    total_timesteps  | 10752     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 131       |
# |    n_updates        | 10751     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.42e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 18        |
# |    time_elapsed     | 656       |
# |    total_timesteps  | 12096     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 161       |
# |    n_updates        | 12095     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -8.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 18        |
# |    time_elapsed     | 725       |
# |    total_timesteps  | 13440     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 132       |
# |    n_updates        | 13439     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -7.98e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 18        |
# |    time_elapsed     | 795       |
# |    total_timesteps  | 14784     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 126       |
# |    n_updates        | 14783     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 336       |
# |    ep_rew_mean      | -7.71e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 18        |
# |    time_elapsed     | 866       |
# |    total_timesteps  | 16128     |
# | train/              |           |
# |    learning_rate    | 0.01      |
# |    loss             | 161       |
# |    n_updates        | 16127     |
# -----------------------------------
# model saved at: Saved Models/DQN_switch_1_27_50
# memory buffer saved

# %%
import pickle
import pandas as pd

buf = model.replay_buffer

obs = buf.observations.reshape(len(buf.observations), -1)
next_obs = buf.next_observations.reshape(len(buf.next_observations), -1)
actions = buf.actions.reshape(len(buf.actions), -1)
rewards = buf.rewards.reshape(len(buf.rewards), -1)
dones = buf.dones.reshape(len(buf.dones), -1)

# Build dataframe
df = pd.DataFrame(
    np.hstack([obs, actions, rewards, dones, next_obs]),
    columns=[
        *[f"obs_{i}" for i in range(obs.shape[1])],
        "action",
        "reward",
        "done",
        *[f"next_obs_{i}" for i in range(next_obs.shape[1])]
    ]
)

# Save CSV
csv_path = "Memory Buffers/DQN_switch_1_27_50.csv"
df.to_csv(csv_path, index=False)
