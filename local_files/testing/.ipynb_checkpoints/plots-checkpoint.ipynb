# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dfs = [
    load_controller_csv("sac_single_temp.csv", "SAC_T"),
    load_controller_csv("dqn_single_temp.csv", "DQN_T"),
    load_controller_csv("dqn_single_switch.csv", "DQN_S"),
    load_controller_csv("sac_single_temp.csv", "SAC_S"),
]

# %%
plt.figure()
plt.scatter(total_energy, total_discomfort)
plt.xlabel("Total Energy [kWh]")
plt.ylabel("Thermal Discomfort [°C·h]")
plt.yscale("log")
plt.title("Energy vs Thermal Discomfort")
plt.show()
